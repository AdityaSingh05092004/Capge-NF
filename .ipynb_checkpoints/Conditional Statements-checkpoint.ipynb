# %%
## Q1 Leap Year Program
a=int(input("Enter a year :"))
if(a%4==0 and a%100!=0 ) or (a%400==0):
    print("Leap year")
else:
    print("Not a Leap Year")
# Out:
# Enter a year : 1900
# Not a Leap Year

# %%
## Q2 Largest among 3 Numbers 
a=int(input("Enter First Number:"))
b=int(input("Enter First Number:"))
c=int(input("Enter First Number:"))
if(a>b):
    if(a>c):
        print("Largest Number is:",a)
    else:
        print("Largest Number is:",c)
else:
    print("Largest Number is:",b)
# Out:
# Enter First Number: 2
# Enter First Number: 1
# Enter First Number: 8
# Largest Number is: 8

# %%
## Q3 Character checker 
a=input("Enter a Character:")
if(a.isupper()):
    print("Uppercase Letter")
elif(a.islower()):
    print("Lowercase Letter")
elif(a.isdigit()):
    print("Digit")
else:
    print("Special Character")
# Out:
# Enter a Character: q
# Lowercase Letter

# %%
## Q4 Electricity bill calculator
a=int(input("Enter Electricity Units:"))
if(a<=100):
    b=a*2
elif(a<=200):
    b=a*3
else:
    b=a*5
print("Electricity Bill:₹",b)
# Out:
# Enter Electricity Units: 300
# Electricity Bill:₹ 1500

# %%
## Q5 Triangle Program
a=int(input("Enter Triangle Side 1:"))
b=int(input("Enter Triangle Side 2:"))
c=int(input("Enter Triangle Side 3:"))
if(a==b==c):
    print("Equilatorial Triangle")
elif(a==b or b==c or a==c):
    print('Isosceles Triangle')
else:
    print("Scalene Traingle ")
# Out:
# Enter Triangle Side 1: 2
# Enter Triangle Side 2: 3
# Enter Triangle Side 3: 4
# Scalene Traingle

# %%
## Q6 Calculator 
a=int(input("Enter a First Number:"))
b=input("Enter an operator (+,-,*,/,):")
c=int(input("Enter a second Number:"))
if(b=="+"):
    print("Result =",a+c)
elif(b=="-"):
    print("Result =",a-c)
elif(b=="*"):
    print("Result =",a*c)
elif(b=="/"):
    print("Result =",a/c)
else:
    print("Ivalid Operator")
# Out:
# Enter a First Number: 2
# Enter an operator (+,-,*,/,): +
# Enter a second Number: 7
# Result = 9

# %%
## Q6 Income Tax Calculator 
a=int(input("Enter Salary:"))
if(a<=400000):
    b="Nil"
elif(a<=800000):
    b=a*0.05
elif(a<=120000):
    b=a*0.10
elif(a<=160000):
    b=a*0.15
elif(a<=200000):
    b=a*0.20
elif(a<=240000):
    b=a*0.25
else:
    b=a*0.30
print("Income Tax:",b)
# Out:
# Enter Salary: 123456
# Income Tax: Nil

# %%
## Q8 Login Authentication
a=input("Enter a Username: ")
b=input("Enter A password: ")
if(a=="Aditya" and b=="Aditya98654"):
    print("Login Successful")
else:
    print("Please Enter a valid Username and Password")
# Out:
# Enter a Username:  Aditya
# Enter A password:  Aditya98654
# Login Successful

# %%
##Q9 Point Position 
x=int(input("Enter X Coordinate:"))
y=int(input("Enter Y Coordinate:"))
if(x>0 and y>0):
    print("First Quadrant")
elif(x<0 and y>0):
    print("Second Quadrant")
elif (x<0 and y<0):
    print("Third Quadrant")
elif (x>0 and y<0):
    print("Fourth Quadrant")
elif (x==0 and y==0):
    print("At Origin")
else:
    print("On Axis")
# Out:
# Enter X Coordinate: 0
# Enter Y Coordinate: 0
# At Origin

# %%
## Q10 Grade Assignment Program
a=int(input("Enter Marks:"))
if(a>=90):
    print("Grade A ")
    print("Distinction")
elif(a>=75):
    print("Grade B ")
elif(a>=60):
    print("Grade C ")
elif(a>=40):
    print("Grade A ")
else:
    print("Fail")
# Out:
# Enter Marks: 90
# Grade A
# Distinction
